# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#mounting the drive to access the dataset from the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#we now assign aour data to the variable "data"
data = '/content/drive/MyDrive/dropout1.csv'

# %%
import pandas as pd

# Specify the file path of the CSV file in your Google Drive
file_path = '/content/drive/MyDrive/dropout1.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %% [markdown]
# # DATA EXPLORATION

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
# Print column names
print(df.columns.tolist())
# Out:
# ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP', 'Target']

# %%
#Check for missing values in the dataset
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %% [markdown]
# from the output above we are availbe to determine there were no missing values

# %%
# Get a summary of the dataset
summary = df.describe()
print(summary)
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# ...

# %% [markdown]
# **reversing the encoding of a categorical variable. It involves mapping the encoded values back to their original labels or categories. In this case, the encoded values of 0 and 1 for gender are mapped back to the labels "female" and "male", respectively.**

# %%
# Mapping dictionary gender
gender_mapping = {0: 'female', 1: 'male'}

# Replace encoded values with corresponding labels
df['Gender'] = df['Gender'].map(gender_mapping)

# Print the Gender column
print(df['Gender'])
# Out:
# 0         male
# 1         male
# 2         male
# 3       female
# 4       female
#          ...
# 4419      male
# 4420    female
# 4421    female
# 4422    female
# 4423    female
# Name: Gender, Length: 4424, dtype: object

# %%
#checking if the encoding worked by printing the first 5 rows of the dataset
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#   Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                    Evening                       1            1
# 1                    Evening                       1            1
# 2                    Evening                       1            1
# 3                    Evening                       1            1
# 4                    Daytime                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %% [markdown]
# #**changing the evening time attendance into yes or no**

# %%
# Mapping dictionary gender
gender_mapping = {0: 'Daytime', 1: 'Evening'}

# Replace encoded values with corresponding labels
df['Daytime/evening attendance'] = df['Daytime/evening attendance'].map(gender_mapping)

# Print the Gender column
print(df['Daytime/evening attendance'])
# Out:
# 0       Evening
# 1       Evening
# 2       Evening
# 3       Evening
# 4       Daytime
#          ...
# 4419    Evening
# 4420    Evening
# 4421    Evening
# 4422    Evening
# 4423    Evening
# Name: Daytime/evening attendance, Length: 4424, dtype: object

# %% [markdown]
# # **changing tution fees paid upto date**

# %%
# Mapping dictionary gender
gender_mapping = {0: 'paid_to_date', 1: 'not_paid_to_date'}

# Replace encoded values with corresponding labels
df['Tuition fees up to date'] = df['Tuition fees up to date'].map(gender_mapping)

# Print the Gender column
print(df['Tuition fees up to date'])
# Out:
# 0       not_paid_to_date
# 1           paid_to_date
# 2           paid_to_date
# 3       not_paid_to_date
# 4       not_paid_to_date
#               ...
# 4419    not_paid_to_date
# 4420        paid_to_date
# 4421    not_paid_to_date
# 4422    not_paid_to_date
# 4423    not_paid_to_date
# Name: Tuition fees up to date, Length: 4424, dtype: object

# %% [markdown]
# **changing to know if the student is a debtor or not a debtor**

# %%
# Mapping dictionary gender
gender_mapping = {0: 'debtor', 1: 'not_debtor'}

# Replace encoded values with corresponding labels
df['Debtor'] = df['Debtor'].map(gender_mapping)

# Print the Gender column
print(df['Debtor'])
# Out:
# 0           debtor
# 1           debtor
# 2           debtor
# 3           debtor
# 4           debtor
#            ...
# 4419        debtor
# 4420    not_debtor
# 4421        debtor
# 4422        debtor
# 4423        debtor
# Name: Debtor, Length: 4424, dtype: object

# %%
#changing for marital status
# Mapping dictionary gender
gender_mapping = {0: 'Married', 1: 'not_Married'}

# Replace encoded values with corresponding labels
df['Marital status'] = df['Marital status'].map(gender_mapping)

# Print the Gender column
print(df['Marital status'])
# Out:
# 0       not_Married
# 1       not_Married
# 2       not_Married
# 3       not_Married
# 4               NaN
#            ...
# 4419    not_Married
# 4420    not_Married
# 4421    not_Married
# 4422    not_Married
# 4423    not_Married
# Name: Marital status, Length: 4424, dtype: object

# %%
#changing for marital status
# Mapping dictionary gender
gender_mapping = {0: 'no_special_need', 1: 'special_need'}

# Replace encoded values with corresponding labels
df['Educational special needs'] = df['Educational special needs'].map(gender_mapping)

# Print the Gender column
print(df['Educational special needs'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4419    NaN
# 4420    NaN
# 4421    NaN
# 4422    NaN
# 4423    NaN
# Name: Educational special needs, Length: 4424, dtype: object

# %%
# Save the modified DataFrame to a CSV file
df.to_csv('modified_dataset.csv', index=False)

# %% [markdown]
# # **we encode the categorical variables to visualise our data**

# %%
# Mapping dictionary gender
gender_mapping = {'female':0 , 'male':1}

# Replace encoded values with corresponding labels
df['Gender'] = df['Gender'].map(gender_mapping)

# Print the Gender column
print(df['Gender'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 4419    1
# 4420    0
# 4421    0
# 4422    0
# 4423    0
# Name: Gender, Length: 4424, dtype: int64

# %%
# Mapping dictionary gender
gender_mapping = {'Daytime':0, 'Evening':1}

# Replace encoded values with corresponding labels
df['Daytime/evening attendance'] = df['Daytime/evening attendance'].map(gender_mapping)

# Print the Gender column
print(df['Daytime/evening attendance'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 4419    1
# 4420    1
# 4421    1
# 4422    1
# 4423    1
# Name: Daytime/evening attendance, Length: 4424, dtype: int64

# %%
# Mapping dictionary gender
gender_mapping = {'paid_to_date':0 , 'not_paid_to_date':1 }

# Replace encoded values with corresponding labels
df['Tuition fees up to date'] = df['Tuition fees up to date'].map(gender_mapping)

# Print the Gender column
print(df['Tuition fees up to date'])
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 4419    1
# 4420    0
# 4421    1
# 4422    1
# 4423    1
# Name: Tuition fees up to date, Length: 4424, dtype: int64

# %%
# Mapping dictionary gender
gender_mapping = {'debtor':0 , 'not_debtor':1 }

# Replace encoded values with corresponding labels
df['Debtor'] = df['Debtor'].map(gender_mapping)

# Print the Gender column
print(df['Debtor'])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4419    0
# 4420    1
# 4421    0
# 4422    0
# 4423    0
# Name: Debtor, Length: 4424, dtype: int64

# %%
#changing for marital status
# Mapping dictionary gender
gender_mapping = {'Married':0 , 'not_Married':1 }

# Replace encoded values with corresponding labels
df['Marital status'] = df['Marital status'].map(gender_mapping)

# Print the Gender column
print(df['Marital status'])
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       NaN
#        ...
# 4419    1.0
# 4420    1.0
# 4421    1.0
# 4422    1.0
# 4423    1.0
# Name: Marital status, Length: 4424, dtype: float64

# %% [markdown]
# # **Data visualisation with python**

# %% [markdown]
# # Bar Plot
#
# Visualizing the count of each category in the target variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the target column name
target_column = 'Target'  # Replace 'Target' with the actual column name in your dataset

# Generate a bar plot for the target variable
target_counts = df[target_column].value_counts()
plt.bar(target_counts.index, target_counts.values)
plt.xlabel('Target')
plt.ylabel('Count')
plt.title('Count of each category in the target variable')
plt.show()

# %% [markdown]
# **Heatmap**
#
#  Visualizing the correlation between the target variable and other numerical columns.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select the desired columns
columns_to_include = [ 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance',
                      'Previous qualification', "Mother's qualification", "Father's qualification",
                      "Mother's occupation", "Father's occupation", 'Displaced', 'Debtor',
                      'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
                      'Unemployment rate', 'Inflation rate', 'GDP']

# Subset the DataFrame with the selected columns
subset_df = df[columns_to_include]

# Calculate the correlation matrix
correlation_matrix = subset_df.corr()

# Generate a heatmap of the correlation matrix
plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-50-ebfbcbaf4bb5>:16: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = subset_df.corr()

# %%
# Select the columns for x-axis and y-axis
x_column = 'Marital status' 
y_column = 'Target'  

# Create the scatter plot
plt.scatter(df[x_column], df[y_column])
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot')
plt.show()

# %%
# Select the columns for x-axis and y-axis
x_column = 'GDP' 
y_column = 'Target'  

# Create the scatter plot
plt.scatter(df[x_column], df[y_column])
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot')
plt.show()

# %%
# Select the columns for x-axis and y-axis
x_column = 'Inflation rate' 
y_column = 'Target'  

# Create the scatter plot
plt.scatter(df[x_column], df[y_column])
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# **A machine learning model**
#
# is a mathematical representation or algorithm that is designed to learn patterns and make predictions or decisions from data. It is trained using historical or labeled data, and its purpose is to generalize the patterns in the training data to make accurate predictions on new, unseen data.
#
# Machine learning models can be classified into different types based on the learning approach and the task they are designed for. Some common types of machine learning models include:

# %% [markdown]
# **For Classification: ml model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingClassifier

# Select the columns for training the model
columns = ['Marital status','Daytime/evening attendance',
           'Previous qualification', "Mother's qualification", "Father's qualification",
           "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor',
           'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
           'Unemployment rate', 'Inflation rate', 'GDP']

# Select the target variable column
target_column = 'Target'  # Replace 'Target' with the actual column name for the target variable

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[columns], df[target_column], test_size=0.2, random_state=42)

# Create the gradient boosting classifier
model = HistGradientBoostingClassifier()

# Train the model on the training data
model.fit(X_train, y_train)

# Function to get user input for variables
def get_user_input():
    user_input = {}
    for column in columns:
        user_input[column] = input(f"Enter value for {column}: ")
    return pd.DataFrame([user_input])

# Get user input for variables
user_data = get_user_input()

# Make predictions on the user input
prediction = model.predict(user_data)

# Print the prediction result
print("Prediction: ", prediction[0])

# %% [markdown]
# **Histgradient boosting classifier**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.preprocessing import LabelEncoder


# Select the columns for training the model
columns = ['Marital status',  'Daytime/evening attendance',
           'Previous qualification', "Mother's qualification", "Father's qualification",
           "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor',
           'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment'
           'Unemployment rate', 'Inflation rate', 'GDP']

# Select the target variable column
target_column = 'Target'  # Replace 'Target' with the actual column name for the target variable

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[columns], df[target_column], test_size=0.2, random_state=42)

# Encode categorical variables in training data
label_encoder = LabelEncoder()
for column in X_train.columns:
    if X_train[column].dtype == 'object':
        X_train[column] = label_encoder.fit_transform(X_train[column].astype(str))

# Create the gradient boosting classifier
model = HistGradientBoostingClassifier()

# Train the model on the training data
model.fit(X_train, y_train)

# Function to get user input for variables
def get_user_input():
    user_input = {}
    for column in columns:
        user_input[column] = input(f"Enter value for {column}: ")
    return pd.DataFrame([user_input])

# Get user input for variables
user_data = get_user_input()

# Encode categorical variables in user input
for column in user_data.columns:
    if user_data[column].dtype == 'object':
        user_data[column] = label_encoder.transform(user_data[column].astype(str))

# Make predictions on the user input
prediction = model.predict(user_data)

# Print the prediction result
print("Prediction: ", prediction[0])
